# %% [markdown]
# # odi womens all rounder

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %%
url = 'https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder'

# %%
r =  requests.get(url)

# %%
soup = bs(r.text,'html.parser')

# %%
# Creating the list for saving the scraped data
pos_list = []
player_list  = []
team_list  = []
rating_list = []
career_best_rating_list  = []

# Scraping the position
pos = soup.find('td', class_="rankings-block__position").text
pos_list.append(pos)

# Scraping the player
player = soup.find('div', class_="rankings-block__banner--name-large").text
player_list.append(player)

# Scraping the team name
team = soup.find('div', class_ = "rankings-block__banner--nationality").text.strip().replace('\n','')
team_list.append(team)

# Scraping the rating
rating = soup.find('div', class_="rankings-block__banner--rating").text
rating_list.append(rating)

# %% [markdown]
# scraping the data after first person

# %%
container = soup.find_all('tr', class_="table-body")

for i in container:#[0:1]:

  # Scraping the position
  pos = i.find('td', class_="table-body__cell table-body__cell--position u-text-right").text.strip()
  pos = pos.split('\n') # splitting to get only position
  pos = pos[0] # 
  pos_list.append(pos)
  
  # Scraping the player
  player = i.find('td', class_="table-body__cell rankings-table__name name").text.strip()
  player_list.append(player)

  # Scraping the team
  team = i.find('span', class_="table-body__logo-text").text.strip()
  team_list.append(team)

  # Scraping the rating
  rating = i.find('td', class_="table-body__cell rating").text.strip()
  rating_list.append(rating)

# %%
df  = pd.DataFrame({
    'POS' : pos_list,
    'PLAYER' : player_list,
    'TEAM' : team_list,
    'RATING' : rating_list})

# %%
df
# Out:
#                                                   POS             PLAYER TEAM  \
# 0   \n\n\n                            1\n         ...       Ellyse Perry  AUS
# 1                                                   2     Natalie Sciver  ENG
# 2                                                   3     Marizanne Kapp   SA
# 3                                                   4    Hayley Matthews   WI
# 4                                                   5        Amelia Kerr   NZ
# 5                                                   6   Ashleigh Gardner  AUS
# 6                                                   7      Deepti Sharma  IND
# 7                                                   8      Jess Jonassen  AUS
# 8                                                   9     Jhulan Goswami  IND
# 9                                                  10    Stafanie Taylor   WI
# 10                                                 11    Katherine Brunt  ENG
# 11                                                 12      Sophie Devine   NZ
# 12                                                 13          Sune Luus   SA
# 13                                                 14   Dane van Niekerk   SA
# 14                                                 15       Rumana Ahmed  BAN
# 15                                                 16           Nida Dar  PAK
# 16                                                 17  Sophie Ecclestone  ENG
# 17                                                 18     Heather Knight  ENG
# 18                                                 19     Tahlia McGrath  AUS
# 19                                                 20         Kate Cross  ENG
#
#    RATING
# 0     428
# 1     368
# 2     363
# 3     351
# 4     335
# 5     267
# 6     256
# 7     246
# 8     225
# 9     221
# 10    218
# 11    217
# 12    201
# 13    198
# 14    188
# 15    187
# 16    179
# 17    161
# 18    149
# 19    148

# %%
df.head(10)
# Out:
#                                                  POS            PLAYER TEAM  \
# 0  \n\n\n                            1\n         ...      Ellyse Perry  AUS
# 1                                                  2    Natalie Sciver  ENG
# 2                                                  3    Marizanne Kapp   SA
# 3                                                  4   Hayley Matthews   WI
# 4                                                  5       Amelia Kerr   NZ
# 5                                                  6  Ashleigh Gardner  AUS
# 6                                                  7     Deepti Sharma  IND
# 7                                                  8     Jess Jonassen  AUS
# 8                                                  9    Jhulan Goswami  IND
# 9                                                 10   Stafanie Taylor   WI
#
#   RATING
# 0    428
# 1    368
# 2    363
# 3    351
# 4    335
# 5    267
# 6    256
# 7    246
# 8    225
# 9    221
